# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

sh = gc.create('CED19I027_HPC_LAB1_Data')

# Open our new sheet and add some data.
worksheet = gc.open('CED19I027_HPC_LAB1_Data').sheet1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# WARNING:google.auth._default:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable

# %%
cell_list = worksheet.range('A1:A1')
for cell in cell_list:
  cell.value = '#Threads'
worksheet.update_cells(cell_list)

cell_list = worksheet.range('B1:B1')
for cell in cell_list:
  cell.value = 'Execution Time'
worksheet.update_cells(cell_list)

cell_list = worksheet.range('A3:A9')
i = 1;
for cell in cell_list:
  cell.value = 2*i
  i = cell.value
worksheet.update_cells(cell_list)
cell_list = worksheet.range('A2:A2')
for cell in cell_list:
  cell.value = 1
worksheet.update_cells(cell_list)
# Out:
# {'spreadsheetId': '1kZVjE6njctddBWVPkPVLK_GC4cv4oHytwd3CJhLbYdk',
#  'updatedCells': 1,
#  'updatedColumns': 1,
#  'updatedRange': 'Sheet1!A2',
#  'updatedRows': 1}

# %%
worksheet = gc.open('CED19I027_HPC_LAB1_Data').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
#print(rows)


df = pd.DataFrame.from_records(rows)

print(df)

import os

for i in df[0][1:9]:
  command = "gcc -fopenmp vectoraddparallel.c && export OMP_NUM_THREADS="
  command = command + i
  os.system(command)
  command = "./a.out > time_taken.txt"
  os.system(command)
# Out:
#           0               1
# 0  #Threads  Execution Time
# 1         1
# 2         2
# 3         4
# 4         8
# 5        16
# 6        32
# 7        64
# 8       128

# %%
# %%shell
# gcc vectoraddserial.c && ./a.out
# Out:
# gcc: error: vectoraddserial.c: No such file or directory
# gcc: fatal error: no input files
# compilation terminated.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-2-daeeb9d44352> in <module>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'gcc vectoraddserial.c && ./a.out')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_system_commands.py in _shell_cell_magic(args, cmd)
#     107   result = _run_command(cmd, clear_streamed_output=False)
#     108   if not parsed_args.ignore_errors:
# ...
